# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression

# %%
raw_data = pd.read_csv('1.04.+Real-life+example.csv')
raw_data.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %% [markdown]
# **PREPROCESSING**

# %%
raw_data.describe(include = 'all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# unique           4            2          NaN      312
# top         Diesel          yes          NaN  E-Class
# freq          2019         3947          NaN      199
# mean           NaN          NaN  2006.550058      NaN
# std            NaN          NaN     6.719097      NaN
# min            NaN          NaN  1969.000000      NaN
# 25%            NaN          NaN  2003.000000      NaN
# 50%            NaN          NaN  2008.000000      NaN
# 75%            NaN          NaN  2012.000000      NaN
# max            NaN          NaN  2016.000000      NaN

# %% [markdown]
# **##determinig the variable of interest**

# %%
data = raw_data.drop(['Model'], axis=1)
data.describe(include = 'all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# top         Diesel          yes          NaN
# freq          2019         3947          NaN
# mean           NaN          NaN  2006.550058
# std            NaN          NaN     6.719097
# min            NaN          NaN  1969.000000
# 25%            NaN          NaN  2003.000000
# 50%            NaN          NaN  2008.000000
# 75%            NaN          NaN  2012.000000
# max            NaN          NaN  2016.000000

# %% [markdown]
# **#DEALING WITH MISSING VALUES**

# %%
data.isnull()
# Out:
#       Brand  Price   Body  Mileage  EngineV  Engine Type  Registration   Year
# 0     False  False  False    False    False        False         False  False
# 1     False  False  False    False    False        False         False  False
# 2     False  False  False    False    False        False         False  False
# 3     False  False  False    False    False        False         False  False
# 4     False  False  False    False    False        False         False  False
# ...     ...    ...    ...      ...      ...          ...           ...    ...
# 4340  False  False  False    False    False        False         False  False
# 4341  False  False  False    False    False        False         False  False
# 4342  False  False  False    False    False        False         False  False
# 4343  False  False  False    False     True        False         False  False
# 4344  False  False  False    False    False        False         False  False
#
# [4345 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
data_no_mv = data.dropna(axis=0)
data_no_mv.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# top         Diesel          yes          NaN
# freq          1861         3654          NaN
# mean           NaN          NaN  2006.379627
# std            NaN          NaN     6.695595
# min            NaN          NaN  1969.000000
# 25%            NaN          NaN  2003.000000
# 50%            NaN          NaN  2007.000000
# 75%            NaN          NaN  2012.000000
# max            NaN          NaN  2016.000000

# %% [markdown]
# **EXPLORING THE PDFs**

# %%
sns.displot(data_no_mv['Price'], kde=True)

# %% [markdown]
# **DEALING WITH OUTLIERS**

# %%
q = data_no_mv['Price'].quantile(0.99)
data_1 = data_no_mv[data_no_mv['Price']<q]
data_1.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3984    3984.000000   3984  3984.000000  3984.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1528          NaN          NaN
# mean           NaN   17837.117460    NaN   165.116466     2.743770
# std            NaN   18976.268315    NaN   102.766126     4.956057
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    93.000000     1.800000
# 50%            NaN   11400.000000    NaN   160.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         3984         3984  3984.000000
# unique           4            2          NaN
# top         Diesel          yes          NaN
# freq          1853         3613          NaN
# mean           NaN          NaN  2006.292922
# std            NaN          NaN     6.672745
# min            NaN          NaN  1969.000000
# 25%            NaN          NaN  2002.750000
# 50%            NaN          NaN  2007.000000
# 75%            NaN          NaN  2011.000000
# max            NaN          NaN  2016.000000

# %%
sns.displot(data_1['Price'], kde=True)

# %%
sns.displot(data_no_mv['Mileage'], kde=True)

# %%
q  = data_1['Mileage'].quantile(0.99)
data_2 = data_1[data_1['Mileage']<q]

# %%
sns.displot(data_2['Mileage'], kde=True)

# %% [markdown]
# now engine volume

# %%
sns.displot(data_no_mv['EngineV'], kde=True)

# %% [markdown]
# for some extra clarification

# %%
EngV = pd.DataFrame(data_no_mv['EngineV'])
EngV = EngV.dropna(axis=0)
EngV.sort_values(by = 'EngineV')
# Out:
#       EngineV
# 2512     0.60
# 188      0.65
# 345      1.00
# 2432     1.00
# 804      1.00
# ...       ...
# 2349    99.99
# 930     99.99
# 3641    99.99
# 256     99.99
# 3114    99.99
#
# [4025 rows x 1 columns]

# %%
data_3 = data_2[data_2['EngineV']<6.5]

# %%
sns.displot(data_3['EngineV'], kde=True)

# %%
sns.displot(data_no_mv['Year'])

# %%
q = data_3['Year'].quantile(0.01)
data_4 = data_3[data_3['Year']>q]

# %%
sns.displot(data_4['Year'], kde=True)

# %%
data_cleaned = data_4.reset_index(drop = True)

# %%
data_cleaned.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3867    3867.000000   3867  3867.000000  3867.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           848            NaN   1467          NaN          NaN
# mean           NaN   18194.455679    NaN   160.542539     2.450440
# std            NaN   19085.855165    NaN    95.633291     0.949366
# min            NaN     800.000000    NaN     0.000000     0.600000
# 25%            NaN    7200.000000    NaN    91.000000     1.800000
# 50%            NaN   11700.000000    NaN   157.000000     2.200000
# 75%            NaN   21700.000000    NaN   225.000000     3.000000
# max            NaN  129222.000000    NaN   435.000000     6.300000
#
#        Engine Type Registration         Year
# count         3867         3867  3867.000000
# unique           4            2          NaN
# top         Diesel          yes          NaN
# freq          1807         3505          NaN
# mean           NaN          NaN  2006.709853
# std            NaN          NaN     6.103870
# min            NaN          NaN  1988.000000
# 25%            NaN          NaN  2003.000000
# 50%            NaN          NaN  2008.000000
# 75%            NaN          NaN  2012.000000
# max            NaN          NaN  2016.000000

# %% [markdown]
# **CHECKING THE OLS ASSUMPTIONS**

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3, sharey=True, figsize=(15,3))
ax1.scatter(data_cleaned['Year'], data_cleaned['Price'])
ax1.set_title("Price and Year")

ax2.scatter(data_cleaned['EngineV'], data_cleaned['Price'])
ax2.set_title("Price and EngineV")

ax3.scatter(data_cleaned['Mileage'], data_cleaned['Price'])
ax3.set_title("Price and Mileage")

plt.show()

# %%
sns.displot(data_cleaned['Price'], kde=True)

# %% [markdown]
# **RELAXING THE ASSUMPTIONS**

# %%
log_price = np.log(data_cleaned['Price'])
data_cleaned['log_price'] = log_price
data_cleaned
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3862     Volkswagen   11500.0        van      163      2.5      Diesel
# 3863         Toyota   17900.0      sedan       35      1.6      Petrol
# 3864  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3865            BMW    6500.0      sedan        1      3.5      Petrol
# 3866     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year  log_price
# 0             yes  1991   8.342840
# 1             yes  1999   8.974618
# 2             yes  2003   9.495519
# 3             yes  2007  10.043249
# 4             yes  2011   9.814656
# ...           ...   ...        ...
# 3862          yes  2008   9.350102
# 3863          yes  2014   9.792556
# 3864          yes  2014  11.736069
# 3865          yes  1999   8.779557
# 3866          yes  2013   9.510445
#
# [3867 rows x 9 columns]

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3, sharey=True, figsize=(15,3))
ax1.scatter(data_cleaned['Year'], data_cleaned['log_price'])
ax1.set_title("log_price and Year")

ax2.scatter(data_cleaned['EngineV'], data_cleaned['log_price'])
ax2.set_title("log_price and EngineV")

ax3.scatter(data_cleaned['Mileage'], data_cleaned['log_price'])
ax3.set_title("log_price and Mileage")

plt.show()

# %%
data_cleaned = data_cleaned.drop(['Price'], axis=1)

# %% [markdown]
# **MULTICOLLINEARITY**

# %%
data_cleaned.columns.values
# Out:
# <StringArray>
# [       'Brand',         'Body',      'Mileage',      'EngineV',
#   'Engine Type', 'Registration',         'Year',    'log_price']
# Length: 8, dtype: str

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data_cleaned[['Mileage', 'Year', 'EngineV']]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#          VIF features
# 0   3.791584  Mileage
# 1  10.354854     Year
# 2   7.662068  EngineV

# %%
data_no_multicollinearity = data_cleaned.drop(['Year'], axis=1)

# %% [markdown]
# **CREATE DUMMY VARIABLES**

# %%
data_with_dummies = pd.get_dummies(data_no_multicollinearity, drop_first = True)

# %%
data_with_dummies.head()
# Out:
#    Mileage  EngineV  log_price  Brand_BMW  Brand_Mercedes-Benz  \
# 0      277      2.0   8.342840       True                False
# 1      427      2.9   8.974618      False                 True
# 2      358      5.0   9.495519      False                 True
# 3      240      4.2  10.043249      False                False
# 4      120      2.0   9.814656      False                False
#
#    Brand_Mitsubishi  Brand_Renault  Brand_Toyota  Brand_Volkswagen  \
# 0             False          False         False             False
# 1             False          False         False             False
# 2             False          False         False             False
# 3             False          False         False             False
# 4             False          False          True             False
#
#    Body_hatch  Body_other  Body_sedan  Body_vagon  Body_van  Engine Type_Gas  \
# 0       False       False        True       False     False            False
# 1       False       False       False       False      True            False
# 2       False       False        True       False     False             True
# 3       False       False       False       False     False            False
# 4       False       False       False       False     False            False
#
#    Engine Type_Other  Engine Type_Petrol  Registration_yes
# 0              False                True              True
# 1              False               False              True
# 2              False               False              True
# 3              False                True              True
# 4              False                True              True

# %% [markdown]
# **REARRANGE A BIT**

# %%
data_with_dummies.columns.values
# Out:
# <StringArray>
# [            'Mileage',             'EngineV',           'log_price',
#            'Brand_BMW', 'Brand_Mercedes-Benz',    'Brand_Mitsubishi',
#        'Brand_Renault',        'Brand_Toyota',    'Brand_Volkswagen',
#           'Body_hatch',          'Body_other',          'Body_sedan',
#           'Body_vagon',            'Body_van',     'Engine Type_Gas',
#    'Engine Type_Other',  'Engine Type_Petrol',    'Registration_yes']
# Length: 18, dtype: str

# %%
cols = [   'log_price',         'Mileage',             'EngineV',     
           'Brand_BMW', 'Brand_Mercedes-Benz',    'Brand_Mitsubishi',
       'Brand_Renault',        'Brand_Toyota',    'Brand_Volkswagen',
          'Body_hatch',          'Body_other',          'Body_sedan',
          'Body_vagon',            'Body_van',     'Engine Type_Gas',
   'Engine Type_Other',  'Engine Type_Petrol',    'Registration_yes']
cols
# Out:
# ['log_price',
#  'Mileage',
#  'EngineV',
#  'Brand_BMW',
#  'Brand_Mercedes-Benz',
#  'Brand_Mitsubishi',
#  'Brand_Renault',
#  'Brand_Toyota',
#  'Brand_Volkswagen',
#  'Body_hatch',
#  'Body_other',
#  'Body_sedan',
#  'Body_vagon',
#  'Body_van',
#  'Engine Type_Gas',
#  'Engine Type_Other',
#  'Engine Type_Petrol',
#  'Registration_yes']

# %%
data_preprocessed = data_with_dummies[cols]
data_preprocessed.head()
# Out:
#    log_price  Mileage  EngineV  Brand_BMW  Brand_Mercedes-Benz  \
# 0   8.342840      277      2.0       True                False
# 1   8.974618      427      2.9      False                 True
# 2   9.495519      358      5.0      False                 True
# 3  10.043249      240      4.2      False                False
# 4   9.814656      120      2.0      False                False
#
#    Brand_Mitsubishi  Brand_Renault  Brand_Toyota  Brand_Volkswagen  \
# 0             False          False         False             False
# 1             False          False         False             False
# 2             False          False         False             False
# 3             False          False         False             False
# 4             False          False          True             False
#
#    Body_hatch  Body_other  Body_sedan  Body_vagon  Body_van  Engine Type_Gas  \
# 0       False       False        True       False     False            False
# 1       False       False       False       False      True            False
# 2       False       False        True       False     False             True
# 3       False       False       False       False     False            False
# 4       False       False       False       False     False            False
#
#    Engine Type_Other  Engine Type_Petrol  Registration_yes
# 0              False                True              True
# 1              False               False              True
# 2              False               False              True
# 3              False                True              True
# 4              False                True              True

# %% [markdown]
# **LINEAR REGRSSION MODEL**

# %% [markdown]
# **Declare the inputs and the targets**

# %%
targets = data_preprocessed['log_price']
inputs = data_preprocessed.drop(['log_price'], axis=1)

# %% [markdown]
# **Scale the data**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
inputs_scaled = scaler.transform(inputs)

# %% [markdown]
# **Train_Test_Split**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=365)

# %% [markdown]
# **Create the regression**

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('Targets(y_train)', size=18)
plt.ylabel('Preductions(y_hat)', size=18)
plt.xlim(6, 13)
plt.ylim(6, 13)

plt.show()

# %%
sns.displot(y_train-y_hat, kde=True)
plt.title("Residuals PDF", size = 18)
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %% [markdown]
# **CALCULATE R_Squared**

# %%
reg.score(x_train, y_train)
# Out:
# 0.744996578792662

# %% [markdown]
# **Finding the weights and the bias**

# %%
reg.intercept_
# Out:
# np.float64(9.415239458021299)

# %%
reg.coef_
# Out:
# array([-0.44871341,  0.20903483,  0.0142496 ,  0.01288174, -0.14055166,
#        -0.17990912, -0.06054988, -0.08992433, -0.1454692 , -0.10144383,
#        -0.20062984, -0.12988747, -0.16859669, -0.12149035, -0.03336798,
#        -0.14690868,  0.32047333])

# %%
reg_summary = pd.DataFrame(inputs.columns.values, columns=['Features'])
reg_summary['Weights'] = reg.coef_
reg_summary
# Out:
#                Features   Weights
# 0               Mileage -0.448713
# 1               EngineV  0.209035
# 2             Brand_BMW  0.014250
# 3   Brand_Mercedes-Benz  0.012882
# 4      Brand_Mitsubishi -0.140552
# 5         Brand_Renault -0.179909
# 6          Brand_Toyota -0.060550
# 7      Brand_Volkswagen -0.089924
# 8            Body_hatch -0.145469
# 9            Body_other -0.101444
# 10           Body_sedan -0.200630
# 11           Body_vagon -0.129887
# 12             Body_van -0.168597
# 13      Engine Type_Gas -0.121490
# 14    Engine Type_Other -0.033368
# 15   Engine Type_Petrol -0.146909
# 16     Registration_yes  0.320473

# %%
data_cleaned['Brand'].unique()
# Out:
# <StringArray>
# ['BMW', 'Mercedes-Benz', 'Audi', 'Toyota', 'Renault', 'Volkswagen',
#  'Mitsubishi']
# Length: 7, dtype: str

# %% [markdown]
# **TESTING**

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test, alpha=0.2)
plt.xlabel('Targets(y_test)', size=18)
plt.ylabel('Pedictions(y_hat_test)', size=18)
plt.xlim(6, 13)
plt.ylim(6, 13)

plt.show()

# %%
df_pf = pd.DataFrame(np.exp(y_hat_test), columns=['Predictions'])
df_pf.head()
# Out:
#     Predictions
# 0  10685.501696
# 1   3499.255242
# 2   7553.285218
# 3   7463.963017
# 4  11353.490075

# %%
df_pf['Targets'] = np.exp(y_test)
df_pf
# Out:
#       Predictions  Targets
# 0    10685.501696      NaN
# 1     3499.255242   7900.0
# 2     7553.285218      NaN
# 3     7463.963017      NaN
# 4    11353.490075      NaN
# ..            ...      ...
# 769  29651.726363   6950.0
# 770  10732.071179      NaN
# 771  13922.446953      NaN
# 772  27487.751303      NaN
# 773  13491.163043      NaN
#
# [774 rows x 2 columns]

# %%
y_test = y_test.reset_index(drop=True)
y_test.head()
# Out:
# 0    7.740664
# 1    7.937375
# 2    7.824046
# 3    8.764053
# 4    9.121509
# Name: log_price, dtype: float64

# %%
df_pf['Targets'] = np.exp(y_test)
df_pf
# Out:
#       Predictions  Targets
# 0    10685.501696   2300.0
# 1     3499.255242   2800.0
# 2     7553.285218   2500.0
# 3     7463.963017   6400.0
# 4    11353.490075   9150.0
# ..            ...      ...
# 769  29651.726363  29500.0
# 770  10732.071179   9600.0
# 771  13922.446953  18300.0
# 772  27487.751303  68500.0
# 773  13491.163043  10800.0
#
# [774 rows x 2 columns]

# %%
df_pf['Residuals'] = df_pf['Targets'] - df_pf['Predictions']

# %%
df_pf['Difference %'] = np.absolute(df_pf['Residuals']/(df_pf['Targets']) * 100)
df_pf
# Out:
#       Predictions  Targets     Residuals  Difference %
# 0    10685.501696   2300.0  -8385.501696    364.587030
# 1     3499.255242   2800.0   -699.255242     24.973402
# 2     7553.285218   2500.0  -5053.285218    202.131409
# 3     7463.963017   6400.0  -1063.963017     16.624422
# 4    11353.490075   9150.0  -2203.490075     24.081859
# ..            ...      ...           ...           ...
# 769  29651.726363  29500.0   -151.726363      0.514327
# 770  10732.071179   9600.0  -1132.071179     11.792408
# 771  13922.446953  18300.0   4377.553047     23.921055
# 772  27487.751303  68500.0  41012.248697     59.871896
# 773  13491.163043  10800.0  -2691.163043     24.918176
#
# [774 rows x 4 columns]

# %%
df_pf.describe()
# Out:
#         Predictions        Targets     Residuals  Difference %
# count    774.000000     774.000000    774.000000    774.000000
# mean   15946.760167   18165.817106   2219.056939     36.256693
# std    13133.197604   19967.858908  10871.218143     55.066507
# min     1320.562768    1200.000000 -29456.498331      0.062794
# 25%     7413.644234    6900.000000  -2044.191251     12.108022
# 50%    11568.168859   11600.000000    142.518577     23.467728
# 75%    20162.408805   20500.000000   3147.343497     39.563570
# max    77403.055224  126000.000000  85106.162329    512.688080

# %%
pd.options.display.max_rows=999
pd.set_option('display.float_format', lambda x:'% .2f' %x)
df_pf.sort_values(by = ['Difference %'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\core\frame.py:1201, in DataFrame.__repr__(self)
#    1197             self.info(buf=buf)
#    1198             return buf.getvalue()
#    1199
#    1200         repr_params = fmt.get_dataframe_repr_params()
# -> 1201         return self.to_string(**repr_params)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\core\frame.py:1380, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1376                 max_cols=max_cols,
#    1377                 show_dimensions=show_dimensions,
#    1378                 decimal=decimal,
#    1379             )
# -> 1380             return fmt.DataFrameRenderer(formatter).to_string(
#    1381                 buf=buf,
#    1382                 encoding=encoding,
#    1383                 line_width=line_width,
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:973, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#     970 from pandas.io.formats.string import StringFormatter
#     972 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# --> 973 string = string_formatter.to_string()
#     974 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = f"{text}{self.fmt.dimensions_info}"
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:476, in DataFrameFormatter.get_strcols(self)
#     472 def get_strcols(self) -> list[list[str]]:
#     473     """
#     474     Render a DataFrame to a list of columns (as lists of strings).
#     475     """
# --> 476     strcols = self._get_strcols_without_index()
#     478     if self.index:
#     479         str_index = self._get_formatted_index(self.tr_frame)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:740, in DataFrameFormatter._get_strcols_without_index(self)
#     736 cheader = str_columns[i]
#     737 header_colwidth = max(
#     738     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     739 )
# --> 740 fmt_values = self.format_col(i)
#     741 fmt_values = _make_fixed_width(
#     742     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     743 )
#     745 max_len = max(*(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:754, in DataFrameFormatter.format_col(self, i)
#     752 frame = self.tr_frame
#     753 formatter = self._get_formatter(i)
# --> 754 return format_array(
#     755     frame.iloc[:, i]._values,
#     756     formatter,
#     757     float_format=self.float_format,
#     758     na_rep=self.na_rep,
#     759     space=self.col_space.get(frame.columns[i]),
#     760     decimal=self.decimal,
#     761     leading_space=self.index,
#     762 )
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1172, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting, fallback_formatter)
#    1156     digits = get_option("display.precision")
#    1158 fmt_obj = fmt_klass(
#    1159     values,
#    1160     digits=digits,
#    (...)   1169     fallback_formatter=fallback_formatter,
#    1170 )
# -> 1172 return fmt_obj.get_result()
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1205, in _GenericArrayFormatter.get_result(self)
#    1204 def get_result(self) -> list[str]:
# -> 1205     fmt_values = self._format_strings()
#    1206     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1480, in FloatArrayFormatter._format_strings(self)
#    1479 def _format_strings(self) -> list[str]:
# -> 1480     return list(self.get_result_as_array())
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1397, in FloatArrayFormatter.get_result_as_array(self)
#    1394     return np.array(formatted_lst).reshape(values.shape)
#    1396 if self.formatter is not None:
# -> 1397     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1399 if self.fixed_width:
#    1400     threshold = get_option("display.chop_threshold")
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1360, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1354 def format_with_na_rep(
#    1355     values: ArrayLike, formatter: Callable, na_rep: str
#    1356 ) -> np.ndarray:
#    1357     mask = isna(values)
#    1358     formatted = np.array(
#    1359         [
# -> 1360             formatter(val) if not m else na_rep
#    1361             for val, m in zip(values.ravel(), mask.ravel(), strict=True)
#    1362         ]
#    1363     ).reshape(values.shape)
#    1364     return formatted
#
# Cell In[152], line 2, in <lambda>(x)
# ----> 2 pd.set_option('display.float_format', lambda x:'% . 2f' %x)
#
# ValueError: unsupported format character ' ' (0x20) at index 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\core\frame.py:1244, in DataFrame._repr_html_(self)
#    1240                 max_cols=max_cols,
#    1241                 show_dimensions=show_dimensions,
#    1242                 decimal=".",
#    1243             )
# -> 1244             return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1245         else:
#    1246             return None
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:947, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#     938 Klass = NotebookFormatter if notebook else HTMLFormatter
#     940 html_formatter = Klass(
#     941     self.fmt,
#     942     classes=classes,
#    (...)    945     render_links=render_links,
#     946 )
# --> 947 string = html_formatter.to_string()
#     948 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\html.py:89, in HTMLFormatter.to_string(self)
#      88 def to_string(self) -> str:
# ---> 89     lines = self.render()
#      90     if any(isinstance(x, str) for x in lines):
#      91         lines = [str(x) for x in lines]
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\html.py:655, in NotebookFormatter.render(self)
#     653 self.write("<div>")
#     654 self.write_style()
# --> 655 super().render()
#     656 self.write("</div>")
#     657 return self.elements
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\html.py:95, in HTMLFormatter.render(self)
#      94 def render(self) -> list[str]:
# ---> 95     self._write_table()
#      97     if self.should_show_dimensions:
#      98         by = chr(215)  # ×  # noqa: RUF003
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\html.py:273, in HTMLFormatter._write_table(self, indent)
#     270 if self.fmt.header or self.show_row_idx_names:
#     271     self._write_header(indent + self.indent_delta)
# --> 273 self._write_body(indent + self.indent_delta)
#     275 self.write("</table>", indent)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\html.py:425, in HTMLFormatter._write_body(self, indent)
#     423 def _write_body(self, indent: int) -> None:
#     424     self.write("<tbody>", indent)
# --> 425     fmt_values = self._get_formatted_values()
#     427     # write values
#     428     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\html.py:618, in NotebookFormatter._get_formatted_values(self)
#     617 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 618     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:754, in DataFrameFormatter.format_col(self, i)
#     752 frame = self.tr_frame
#     753 formatter = self._get_formatter(i)
# --> 754 return format_array(
#     755     frame.iloc[:, i]._values,
#     756     formatter,
#     757     float_format=self.float_format,
#     758     na_rep=self.na_rep,
#     759     space=self.col_space.get(frame.columns[i]),
#     760     decimal=self.decimal,
#     761     leading_space=self.index,
#     762 )
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1172, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting, fallback_formatter)
#    1156     digits = get_option("display.precision")
#    1158 fmt_obj = fmt_klass(
#    1159     values,
#    1160     digits=digits,
#    (...)   1169     fallback_formatter=fallback_formatter,
#    1170 )
# -> 1172 return fmt_obj.get_result()
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1205, in _GenericArrayFormatter.get_result(self)
#    1204 def get_result(self) -> list[str]:
# -> 1205     fmt_values = self._format_strings()
#    1206     return _make_fixed_width(fmt_values, self.justify)
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1480, in FloatArrayFormatter._format_strings(self)
#    1479 def _format_strings(self) -> list[str]:
# -> 1480     return list(self.get_result_as_array())
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1397, in FloatArrayFormatter.get_result_as_array(self)
#    1394     return np.array(formatted_lst).reshape(values.shape)
#    1396 if self.formatter is not None:
# -> 1397     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1399 if self.fixed_width:
#    1400     threshold = get_option("display.chop_threshold")
#
# File ~\miniconda3-pbe\envs\python-3.14\Lib\site-packages\pandas\io\formats\format.py:1360, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1354 def format_with_na_rep(
#    1355     values: ArrayLike, formatter: Callable, na_rep: str
#    1356 ) -> np.ndarray:
#    1357     mask = isna(values)
#    1358     formatted = np.array(
#    1359         [
# -> 1360             formatter(val) if not m else na_rep
#    1361             for val, m in zip(values.ravel(), mask.ravel(), strict=True)
#    1362         ]
#    1363     ).reshape(values.shape)
#    1364     return formatted
#
# Cell In[152], line 2, in <lambda>(x)
# ----> 2 pd.set_option('display.float_format', lambda x:'% . 2f' %x)
#
# ValueError: unsupported format character ' ' (0x20) at index 3
